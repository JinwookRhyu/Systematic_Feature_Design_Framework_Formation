# %%
from SPA import main_SPA
from pandas import read_excel
import glob, os

mode = 'agnostic' # 'agnostic' / 'autoML' / 'designed'
if_logtransform = False # True / False

# %%
# %pip install scikit-learn==1.3.2 

if mode == 'agnostic':
    dir_datafile = os.path.dirname(os.getcwd()) + "/Features_agnostic"

    if not os.path.exists(os.path.dirname(os.getcwd()) + "/SPA_results_agnostic"):
        os.mkdir(os.path.dirname(os.getcwd()) + "/SPA_results_agnostic")

    data_name_list = os.listdir(dir_datafile)
    
    for ii in range(len(data_name_list)):
        data_name = data_name_list[ii].replace('.xlsx', '')
        Data = read_excel(dir_datafile + "/" + data_name + ".xlsx", header = None)
    
        if Data.shape[1] > 1:
            if if_logtransform:
                main_SPA(data_name=os.path.dirname(os.getcwd()) + "/Features_agnostic/log_" + data_name,
                         main_data=dir_datafile + "/" + data_name + ".xlsx",
                         save_name=os.path.dirname(os.getcwd()) + "/SPA_results_agnostic/log_" + data_name + ".pkl",
                         interrogation_plot_name = "log_" + data_name,
                         model_name=['XGB', 'RF', 'SVR', 'EN', 'RR', 'PLS', 'SPLS', 'ALVEN1', 'LCEN1', 'ALVEN2', 'LCEN2', 'ALVEN3', 'LCEN3'],
                         interpretable=True, robust_priority=False, group_name='group_labels.txt', spectral_data=False,
                         plot_interrogation=True, nested_cv=True, num_outer = 5, K_fold=10, Nr=1, alpha_num=20, degree=[1],
                         log_transform=if_logtransform)
            else:
                main_SPA(data_name=os.path.dirname(os.getcwd()) + "/Features_agnostic/" + data_name,
                         main_data=dir_datafile + "/" + data_name + ".xlsx",
                         save_name=os.path.dirname(os.getcwd()) + "/SPA_results_agnostic/" + data_name + ".pkl",
                         interrogation_plot_name=data_name,
                         model_name=['XGB', 'RF', 'SVR', 'EN', 'RR', 'PLS', 'SPLS', 'ALVEN1', 'LCEN1', 'ALVEN2', 'LCEN2', 'ALVEN3', 'LCEN3'],
                         interpretable=True, robust_priority = False, group_name='group_labels.txt', spectral_data=False,
                         plot_interrogation=True, nested_cv=True, num_outer = 5,K_fold=10, Nr=1, alpha_num=20, degree=[1], log_transform=if_logtransform)

elif mode == 'autoML':
    dir_datafile = os.path.dirname(os.getcwd()) + "/Features_tsfresh_autoML"
    # Navigate to the directory with Features_tsfresh_autoML folder. This SPA code also can be used for agnostic models when replacing "Features_tsfresh_autoML" with "Features_agnostic" and also from "SPA_results_autoML" with "SPA_results_agnostic"
    data_name_list = os.listdir(dir_datafile)

    if not os.path.exists(os.path.dirname(os.getcwd()) + "/SPA_results_autoML"):
        os.mkdir(os.path.dirname(os.getcwd()) + "/SPA_results_autoML")
    
    for ii in range(len(data_name_list)):
        data_name = data_name_list[ii].replace('.xlsx', '')
        Data = read_excel(dir_datafile + "/" + data_name + ".xlsx", header = None)
    
        if Data.shape[1] > 1:
            if if_logtransform:
                main_SPA(data_name=os.path.dirname(os.getcwd()) + "/Features_tsfresh_autoML/log_" + data_name,
                         main_data=dir_datafile + "/" + data_name + ".xlsx",
                         save_name=os.path.dirname(os.getcwd()) + "/SPA_results_autoML/log_" + data_name + ".pkl",
                         interrogation_plot_name = "log_" + data_name,
                         model_name=['XGB', 'RF', 'SVR', 'ALVEN', 'LCEN', 'EN', 'RR', 'PLS'],
                         interpretable=True, robust_priority=False, group_name='group_labels.txt', spectral_data=False,
                         plot_interrogation=True, nested_cv=True, num_outer = 5, K_fold=10, Nr=1, alpha_num=20, degree=[1],
                         log_transform=if_logtransform)
            else:
                main_SPA(data_name=os.path.dirname(os.getcwd()) + "/Features_tsfresh_autoML/" + data_name,
                         main_data=dir_datafile + "/" + data_name + ".xlsx",
                         save_name=os.path.dirname(os.getcwd()) + "/SPA_results_autoML/" + data_name + ".pkl",
                         interrogation_plot_name=data_name,
                         model_name=['XGB', 'RF', 'SVR', 'ALVEN', 'LCEN', 'EN', 'RR', 'PLS'],
                         interpretable=True, robust_priority = False, group_name='group_labels.txt', spectral_data=False,
                         plot_interrogation=True, nested_cv=True, num_outer = 5,K_fold=10, Nr=1, alpha_num=20, degree=[1], log_transform=if_logtransform)

elif mode == 'designed':
    dir_datafile = os.path.dirname(os.getcwd()) + "/Features_designed"
    data_name_list = os.listdir(dir_datafile)

    if not os.path.exists(os.path.dirname(os.getcwd()) + "/SPA_results_designed_outer"):
        os.mkdir(os.path.dirname(os.getcwd()) + "/SPA_results_designed_outer")

    data_type = "log_B_Q_V"
    data_name_list = []
    test_data_list = []
    grouplabel_list = []
    for k in range(5):
        data_name_list.append(data_type + "_train_Outer_" + str(k+1) + ".xlsx")
        test_data_list.append(data_type + "_test_Outer_" + str(k + 1) + ".xlsx")
        grouplabel_list.append(data_type + "_grouplabel_Outer_" + str(k + 1) + ".xlsx")
    
    if_logtransform = False # log already applied in the designed features
    
    for ii in range(len(data_name_list)):
        data_name = data_name_list[ii].replace('.xlsx', '')
        test_data = test_data_list[ii]
        grouplabel = grouplabel_list[ii]
        Data = read_excel(dir_datafile + "/" + data_name + ".xlsx", header = None)
    
        if Data.shape[1] > 1:
            if if_logtransform:
                main_SPA(data_name=os.path.dirname(os.getcwd()) + "/Features_designed/log_" + data_name,
                         main_data=dir_datafile + "/" + data_name + ".xlsx",
                         test_data = os.path.dirname(os.getcwd()) + "/Features_designed/" + test_data,
                         save_name=os.path.dirname(os.getcwd()) + "/SPA_results_designed_outer/log_" + data_name + ".pkl",
                         interrogation_plot_name = "log_" + data_name,
                         model_name=['XGB', 'RF', 'SVR', 'EN', 'RR', 'PLS', 'SPLS', 'ALVEN1', 'LCEN1', 'ALVEN2', 'LCEN2', 'ALVEN3', 'LCEN3'],
                         interpretable=True, robust_priority=False, group_name=os.path.dirname(os.getcwd()) + "/Features_designed/" + grouplabel, spectral_data=False,
                         plot_interrogation=True, nested_cv=False, num_outer = 5, K_fold=10, Nr=1, alpha_num=20, degree=[1],
                         log_transform=if_logtransform)
            else:
                main_SPA(data_name=os.path.dirname(os.getcwd()) + "/Features_designed/" + data_name,
                         main_data=dir_datafile + "/" + data_name + ".xlsx",
                         test_data=os.path.dirname(os.getcwd()) + "/Features_designed/" + test_data,
                         save_name=os.path.dirname(os.getcwd()) + "/SPA_results_designed_outer/" + data_name + ".pkl",
                         interrogation_plot_name=data_name,
                         model_name=['XGB', 'RF', 'SVR', 'EN', 'RR', 'PLS', 'SPLS', 'ALVEN1', 'LCEN1', 'ALVEN2', 'LCEN2', 'ALVEN3', 'LCEN3'],
                         interpretable=True, robust_priority = False, group_name=os.path.dirname(os.getcwd()) + "/Features_designed/" + grouplabel, spectral_data=False,
                         plot_interrogation=True, nested_cv=False, num_outer = 5,K_fold=10, Nr=1, alpha_num=20, degree=[1], log_transform=if_logtransform)

    if not os.path.exists(os.path.dirname(os.getcwd()) + "/SPA_results_designed"):
        os.mkdir(os.path.dirname(os.getcwd()) + "/SPA_results_designed")
    import pickle
    history = {}
    for k in range(5):
        with open(os.path.dirname(os.getcwd()) + "/SPA_results_designed_outer/" + data_type + "_train_Outer_" + str(k+1) + ".pkl", 'rb') as file:
            history_outer = pickle.load(file)
        keylist = list(history_outer.keys())
        for key in keylist:
            if k == 0:
                history[key] = {}
            if key in history_outer.keys():
                history[key][k] = history_outer[key][0]
    
    with open(os.path.dirname(os.getcwd()) + "/SPA_results_designed/" + data_type + "_designed.pkl", 'wb') as f:
        pickle.dump(history, f)
# Out:
# Requirement already satisfied: scikit-learn==1.3.2 in c:\users\jinwook\anaconda3\envs\hdreganalytics\lib\site-packages (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\jinwook\anaconda3\envs\hdreganalytics\lib\site-packages (from scikit-learn==1.3.2) (1.12.0)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\jinwook\anaconda3\envs\hdreganalytics\lib\site-packages (from scikit-learn==1.3.2) (1.26.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jinwook\anaconda3\envs\hdreganalytics\lib\site-packages (from scikit-learn==1.3.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jinwook\anaconda3\envs\hdreganalytics\lib\site-packages (from scikit-learn==1.3.2) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Nested GroupKFold will be used.
# Beginning nested CV loop 1
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 120 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 2
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 120 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 3
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 120 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 4
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 120 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 5
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 120 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# The best model is XGB. View its results via fitting_result["XGB"] or by opening the SPA_results json/pickle files.
# Nested GroupKFold will be used.
# Beginning nested CV loop 1
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 80 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 2
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 80 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 3
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 80 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 4
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 80 hyperparameter combinations
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# Beginning nested CV loop 5
# There are 35 hyperparameter combinations
# Completed model XGB
# Completed model RF
# Completed model SVR
# There are 240 hyperparameter combinations
#
# Completed model EN
# Completed model RR
# Completed model PLS
# There are 80 hyperparameter combinations
#
# Completed model SPLS
# There are 240 hyperparameter combinations
#
# Completed model ALVEN1
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN1
# There are 240 hyperparameter combinations
#
# Completed model ALVEN2
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN2
# There are 240 hyperparameter combinations
#
# Completed model ALVEN3
# Beginning variable selection runs. There are 21 hyperparameter combinations
# Beginning real runs. There are 252 hyperparameter combinations
# Completed model LCEN3
# The best model is LCEN3. View its results via fitting_result["LCEN3"] or by opening the SPA_results json/pickle files.
